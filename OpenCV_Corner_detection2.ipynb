# %% [markdown]
# <a href="https://colab.research.google.com/github/mmadyda/OpenCV/blob/master/OpenCV_Corner_detection2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
real_chess = cv2.imread('real_chess.jpg')
real_chess = cv2.cvtColor(real_chess, cv2.COLOR_BGR2RGB)
gray_real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2GRAY)

flat_chess = cv2.imread('flat_chess.jpg')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)
gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)

# %%
corners = cv2.goodFeaturesToTrack(gray_flat_chess, 100, 0.01, 10)

# %%
corners = np.int0(corners)

# %%
corners

# %%
for i in corners:
  x, y = i.ravel()
  cv2.circle(flat_chess, (x, y), 3,(255,0,0),-1)

# %%
plt.imshow(flat_chess)

# %%
corners = cv2.goodFeaturesToTrack(gray_real_chess, 500, 0.05, 30)

# %%
corners = np.int8(corners)

# %%
for i in corners:
  x, y = i.ravel()
  cv2.circle(real_chess, (x, y), 3, (255, 0, 0), -1)

# %%
plt.imshow(real_chess)
